# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/hasnaakbarali/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

words = ['running', 'computer', 'eningeering','snowman','dance','dancing','fairy','runs']
lemmatizer = WordNetLemmatizer()

for word in words:
    print(word,'-->',lemmatizer.lemmatize(word,pos='v'))
# Out:
# running --> run
# computer --> computer
# eningeering --> eningeering
# snowman --> snowman
# dance --> dance
# dancing --> dance
# fairy --> fairy
# runs --> run
